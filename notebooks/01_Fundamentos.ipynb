# %% [markdown]
# # 📘 Introducción a Python
# ## Notebook 1 – Fundamentos del lenguaje
#
# **Objetivos de aprendizaje**
# - Entender qué es Python y cómo trabajar en Google Colab / Jupyter.
# - Conocer variables, tipos primitivos y mutabilidad.
# - Usar operadores aritméticos, lógicos y de comparación con criterio.
# - Convertir tipos y comprender la "veracidad" (truthiness) en Python.
# - Manejar entrada/salida y formato de texto con `f-strings`.
#
# **Qué necesitas**: saber usar el teclado y tener ganas 😊.
#
# > Consejo: ejecuta celdas con `Ctrl + Enter` y crea una nueva con `Shift + Enter`.

# %% [markdown]
# ### 🧪 Cómo usar este notebook
# - Las celdas **Markdown** (como esta) contienen teoría e instrucciones.
# - Las celdas **de código** (gris) se ejecutan. Modifícalas y prueba cosas.
# - Al final encontrarás **actividades guiadas**, **retos** y un **mini-proyecto**.

# %% [markdown]
# ## 1. ¿Por qué Python y por qué Colab?
# Python es un lenguaje legible, con tipado dinámico y un ecosistema enorme de librerías.
# Google Colab permite ejecutar Python en la nube sin instalar nada.

# %%
# Prueba rápida: ejecuta esto
print('¡Hola, DAM!') # Muestra por pantalla
print('Versión de Python disponible en este entorno')
import sys # Importamos una librería
print(sys.version)
# Out:
# ¡Hola, DAM!
# Versión de Python disponible en este entorno
# 3.13.9 (tags/v3.13.9:8183fa5, Oct 14 2025, 14:09:13) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# ## 2. Variables, nombres y tipos
# Una **variable** es una referencia a un valor en memoria. En Python no declaras el tipo explícitamente.
#
# **Reglas y buenas prácticas de nombres**
# - snake_case para variables: `total_factura`, `precio_unitario`.
# - Nombres descriptivos mejor que abreviaturas.

# %%
# Ejemplos de variables y tipos básicos
entero = 10              # int
numero_real = 3.1416     # float
texto = 'Ada Lovelace'   # str
es_activo = True         # bool
nada = None              # NoneType

print(f"Variable entero con valor {entero} es de tipo {type(entero).__name__}")
print(f"Variable numero_real con valor {numero_real} es de tipo {type(numero_real).__name__}")
print(f"Variable texto con valor {texto} es de tipo {type(texto).__name__}")
print(f"Variable es_activo con valor {es_activo} es de tipo {type(es_activo).__name__}")
print(f"Variable nada con valor {nada} es de tipo {type(nada).__name__}")
# Out:
# Variable entero con valor 10 es de tipo int
# Variable numero_real con valor 3.1416 es de tipo float
# Variable texto con valor Ada Lovelace es de tipo str
# Variable es_activo con valor True es de tipo bool
# Variable nada con valor None es de tipo NoneType

# %% [markdown]
# ### Listas
# Python tiene soporte para listas como un tipo predefinido del lenguaje. Para crear una lista basta con poner cosas entre [] (corchetes) y separarlas con , (comas).

# %%
print("- Lista con 4 números:")
a=[20,15,7,13] # una lista con cuatro números
print(a)

print("- Lista con 3 strings:")
b=["hola","adios","buen día"] # una lista con tres strings
print(b)

# la función `len` me da la longitud de la lista
print("- Longitud de la lista:")
n=len(a)
print(n)
# Out:
# - Lista con 4 números:
# [20, 15, 7, 13]
# - Lista con 3 strings:
# ['hola', 'adios', 'buen día']
# - Longitud de la lista:
# 4

# %%
# Para acceder a sus elementos, se utiliza el []
# Los índices comienzan en 0

# Lista de ejemplo
b = ["manzana", "pera", "uva", "plátano"]

print("- Elemento con índice 0 de la lista:")
print(b[0])

print("- Elemento con índice 1 de la lista:")
print(b[1])

print("- Elemento con índice 2 de la lista:")
print(b[2])

print("- Elemento con índice -1 de la lista:")
print(b[-1])
# Out:
# - Elemento con índice 0 de la lista:
# manzana
# - Elemento con índice 1 de la lista:
# pera
# - Elemento con índice 2 de la lista:
# uva
# - Elemento con índice -1 de la lista:
# plátano

# %% [markdown]
# ---
# #### Practica clase

# %%
# Usa esta celda para probar diferentes métodos de listas

# %%
a.append(4)
a
# Out:
# [20, 15, 7, 13, 4]

# %%
a.pop()
a
# Out:
# [20, 15, 7, 13]

# %%
print(a[-2]) # Si el índice es negativo se empieza desde atrás
print(a[1:3]) # Copia la lista desde el elemento 1 hasta el elemento 2 (el de antes del 3)
# Out:
# 7
# [15, 7]

# %% [markdown]
# ---

# %% [markdown]
# ### Diccionarios
#
# Un diccionario es una estructura que guarda datos como pares clave–valor.
# Se crean usando llaves `{}` y los pares se escriben así:
# clave: valor.
#
# Son muy útiles para representar objetos del mundo real, como un alumno.

# %%
alumno = {
    "nombre": "Ana",
    "edad": 19,
    "nota": 8.5
}

print("Nombre:", alumno["nombre"])
print("Nota:", alumno["nota"])

# %% [markdown]
# ---
# #### Practica clase

# %%
# Usa esta celda para probar diferentes métodos de diccionarios

# %%
song = {
    "title": "Yellow",
    "singer": "Coldplay",
    "duration_minutes": 3
}

print("Canción:", song["title"])
print("Cantante:", song["singer"])
print("Duración en minutos:", song["duration_minutes"])

song['title'] = "song" #Se puede cambiar las claves de un diccionario
print(song['title'])
# Out:
# Canción: Yellow
# Cantante: Coldplay
# Duración en minutos: 3
# song

# %% [markdown]
# ---

# %% [markdown]
# ### Conjuntos
#
# Los conjuntos (set) se usan para guardar elementos sin duplicados.
# Se crean con {} o con set().

# %%
numeros = {1, 2, 3, 3, 2, 1}
print(numeros)  # Se eliminan duplicados automáticamente
# Out:
# {1, 2, 3}

# %% [markdown]
# ---
# #### Practica clase

# %%
# Usa esta celda para probar diferentes métodos de conjuntos

# %%
nombres = ["Carlos", "Marcos", "Paula", "Marcos", "Paula"]
print(set(nombres))
# Out:
# {'Carlos', 'Paula', 'Marcos'}

# %% [markdown]
# ---

# %% [markdown]
# ### Tuplas
#
# Python también tiene tuplas, que son como listas pero no se pueden modificar (son inmutables).
# Se crean usando paréntesis () y separando los valores con comas.

# %%
tupla = (10, 20, 30)
print("Tupla:", tupla)
print("Primer elemento:", tupla[0])
# Out:
# Tupla: (10, 20, 30)
# Primer elemento: 10

# %%
# Usa esta celda para probar diferentes métodos de tuplas
tupla2 = ("casa", "perro", "elefante")
print("Último elemneto de la tupla: ", tupla2[-1])
# Out:
# Último elemneto de la tupla:  elefante

# %% [markdown]
# ### Mutabilidad y “compartir datos” (aliasing)
# * Hay tipos que no se pueden cambiar una vez creados (son **inmutables**), por ejemplo: `int, float, bool, str, tuple`.
# * Hay tipos que sí se pueden cambiar (son **mutables**), como las listas (list), los diccionarios (dict) o los conjuntos (set).
#
# > A veces dos variables pueden apuntar al mismo dato en memoria. Esto se llama aliasing (como si dos personas tuvieran la misma llave del mismo trastero).

# %%
a = 5
b = a       # ambos valen 5, pero son inmutables
b += 1       # crea un nuevo int para b
print('a:', a, '| b:', b)

lista1 = [1, 2, 3]
lista2 = lista1       # aliasing: referencian la misma lista
lista2.append(4)
print('lista1:', lista1, '| lista2:', lista2)  # ambas cambian
# Out:
# a: 5 | b: 6
# lista1: [1, 2, 3, 4] | lista2: [1, 2, 3, 4]

# %% [markdown]
# ---
# #### Práctica clase

# %%
a = 5
b = a       
a += 1       
print('a:', a, '| b:', b) # Como 'b' es inmutable, aunque creamos un nuevo valor de 'a' 'b' no cambia

lista1 = [1, 2, 3]
lista2 = lista1       # aliasing: referencian la misma lista
lista2.append(4)
print('lista1:', lista1, '| lista2:', lista2)  # ambas cambian
# Out:
# a: 6 | b: 5
# lista1: [1, 2, 3, 4] | lista2: [1, 2, 3, 4]

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Operadores y precedencia
# **Aritméticos**: `+ - * / // % **`
#
# **Comparación**: `== != > < >= <=`
#
# **Lógicos**: `and or not`
#
# La **precedencia** determina qué se evalúa primero (usa paréntesis para claridad).

# %%
a, b = 7, 3
print('suma:', a + b)
print('division real:', a / b)
print('division entera:', a // b)
print('modulo:', a % b)
print('potencia:', a ** b)
print('comparacion a > b:', a > b)
print('logicos (and/or/not):', (a>0) and (b<0), (a>0) or (b<0), not (a==b))
# Out:
# suma: 10
# division real: 2.3333333333333335
# division entera: 2
# modulo: 1
# potencia: 343
# comparacion a > b: True
# logicos (and/or/not): False True True

# %% [markdown]
# ### Truthiness (veracidad) en Python
# Valores considerados **False** en contextos booleanos: `0`, `0.0`, `''` (cadena vacía), `[]`, `{}`, `set()`, `None`.
# Todo lo demás se considera **True**.

# %%
valores = [0, 1, '', 'hola', [], [1], None, {'k':'v'}]
for v in valores:
    print(repr(v), '->', bool(v))

# %% [markdown]
# ## 4. Conversión de tipos (casting)
# - `int('42')`, `float('3.5')`, `str(123)`.
# - Cuidado al convertir cadenas no numéricas: provocan `ValueError`.

# %%
print(int('42') + 8)
print(float('3.5') * 2)
print(str(123) + 'abc')

# Manejo de errores al convertir
try:
    x = int('abc')
except ValueError as e:
    print('Error al convertir:', e)
# Out:
# 50
# 7.0
# 123abc
# Error al convertir: invalid literal for int() with base 10: 'abc'

# %% [markdown]
# ## 5. Cadenas de texto: `f-strings` y métodos útiles
# - **f-strings**: `f'Hola {nombre}'` permiten interpolar variables.
# - Métodos comunes: `.upper()`, `.lower()`, `.strip()`, `.replace()`, `.split()`.
# - **Slicing**: `texto[inicio:fin:paso]`.

# %%
nombre = 'Ada'
edad = 36
print(f'Me llamo {nombre} y tengo {edad} años.')

texto = '  Python para DAM  '
print(texto.upper())
print(texto.strip())
print(texto.replace('DAM', 'Desarrollo'))
print('slice 0:6 ->', texto[0:6])
# Out:
# Me llamo Ada y tengo 36 años.
#   PYTHON PARA DAM
# Python para DAM
#   Python para Desarrollo
# slice 0:6 ->   Pyth

# %%
print(texto.split("p")) #Igua que en Java, crea un array del texto
# Out:
# ['  Python ', 'ara DAM  ']

# %% [markdown]
# ## 6. Entrada y salida con validación
#
# En Python podemos pedir información al usuario usando la función `input()`.
# Cuando se ejecuta, el programa se detiene y espera a que el usuario escriba algo y pulse Enter.
# ```python
# nombre = input("¿Cómo te llamas? ")
# print("Hola,", nombre)
# ```
# > 📌 Importante: Todo lo que devuelve input() es SIEMPRE una cadena de texto (str), aunque parezca un número.

# %%
edad_texto = input('Introduce tu edad: ')
if edad_texto.isdigit():
    edad = int(edad_texto)
    print(f'El año que viene tendrás {edad+1}.')
else:
    print('Por favor introduce un número entero válido.')
# Out:
# Introduce tu edad:  18
# El año que viene tendrás 19.

# %% [markdown]
# ##  7. Introducción a las funciones en Python
#
# En Python, una función es un bloque de código con un nombre, que se puede ejecutar (“llamar”) cuando lo necesites.
# Sirve para reutilizar código, organizar mejor los programas y evitar repetir instrucciones.
#
# * **¿Cómo se define una función?**  Usamos la palabra clave `def`:
# ```python
# def saludar():
#     print("Hola desde una función!")
# ```
# * **¿Cómo se llama una función?**
# ```python
# saludar()
# ```

# %% [markdown]
# ### Funciones con parámetros
# A veces queremos que la función reciba información desde fuera.
# Esa información se llama parámetros (al definir) y argumentos (al llamar).

# %%
def saludar_a(nombre):
    print("Hola,", nombre)

saludar_a("Ana")
saludar_a("Mario")

# %% [markdown]
# ### Funciones que devuelven valores (return)
#
# Una función puede calcular algo y devolverlo:

# %%
def suma(a, b):
    return a + b

resultado = suma(3, 5)
print("La suma es:", resultado)

# %% [markdown]
# ## 7. Buenas prácticas desde el principio
# - Usa nombres descriptivos.
# - Prefiere `f-strings` para formatear.
# - Añade comentarios breves cuando el porqué no sea obvio.
# - Divide problemas en pasos pequeños.
# - Prueba con entradas extremas (0, vacíos, valores grandes…).

# %% [markdown]
# ## 8. Actividades guiadas (paso a paso)
# Cada actividad incluye **enunciado**, **pistas** y **criterios de logro**.
#
# ### Actividad 1 — Calculadora simple (nivel básico)
# **Enunciado**: Pide dos números y muestra suma, resta, producto, división real, división entera y módulo.
#
# **Pistas**: `input()`, `float()`, operadores `+ - * / // %`.
#
# **Criterios**:
# - Convierte entradas a número.
# - Controla división por cero (mensaje claro).

# %%
# 👇 Escribe tu solución aquí
# Sugerencia: usa try/except para division por cero
number1_text = input("Introduce un número: ")
number2_text = input("Introduce otro número: ")
# try:
number1 = float(number1_text)
number2 = float(number2_text)
# except ValueError as e:
#     print ("Números no válidos")
print(f"Suma: {number1 + number2}")
print(f"Resta: {number1 - number2}")
print(f"Producto: {number1 * number2}")
try:
    print(f"División real: {number1 / number2}")
    print(f"División entera: {number1 // number2}")
    print(f"Resto: {number1 % number2}")
except:
    print("No se puede dividir entre 0")
# Out:
# Introduce un número:  5
# Introduce otro número:  4
# Suma: 9.0
# Resta: 1.0
# Producto: 20.0
# División real: 1.25
# División entera: 1.0
# Resto: 1.0

# %% [markdown]
# ### Actividad 2 — Área de círculo (nivel básico)
# **Enunciado**: Pide el radio (float) y muestra el área con dos decimales.
#
# **Pistas**: `area = pi * r**2`, usa `math.pi`, formatea con `:.2f` en `f-strings`.
#
# **Criterios**: entrada válida, resultado formateado.

# %%
# 👇 Tu solución
import math
radio_texto = input("Introduce en radio del círculo: ")
radio = float(radio_texto)
area = math.pi * radio ** 2
print(f"El área del círculo es: {area:.2f}")
# Out:
# Introduce en radio del círculo:  2
# El área del círculo es: 12.57

# %% [markdown]
# ### Actividad 3 — Conversor de temperaturas (C → F) (nivel básico)
# **Enunciado**: Pide grados Celsius y convierte a Fahrenheit.
#
# **Pistas**: `F = C * 9/5 + 32`.
#
# **Criterios**: valida entrada, muestra con 1 decimal.

# %%
# 👇 Tu solución
celsius_text = input("introduce la temperatura en Celsius: ")
celsius = float(celsius_text)
farenheit = celsius * 9/5 + 32
print(f"{celsius} grados Celsius son {farenheit} grados Farenheit")
# Out:
# introduce la temperatura en Celsius:  0
# 0.0 grados Celsius son 32.0 grados Farenheit

# %% [markdown]
# ### Actividad 4 — Par o impar (nivel básico)
# **Enunciado**: Pide un entero y di si es par o impar.
#
# **Pistas**: operador `%`.
#
# **Criterios**: maneja entradas no numéricas. Indica 'Entrada no válida' cuando el valor no es un número.

# %%
# 👇 Tu solución
import sys
number_text = input("Introduce un número: ")
try:
    number = float(number_text)
    if number % 2 == 0:
        print(f"{number} es par")
    else:
        print(f"{number} es impar")
except:
    print("Entrada no válido")
# Out:
# Introduce un número:  h
# Numero no válido

# %% [markdown]
# ### Actividad 5 — Tarjeta de presentación (nivel básico)
# **Enunciado**: Pide `nombre`, `apellidos`, y `edad`, y muestra una tarjeta formateada.
#
# **Pistas**: `f-strings`, `.title()`, validación de edad.
#
# **Criterios**: tratamiento de espacios, capitalización correcta (primera letra se pone en mayúscula aunque la pongamos en minúscula).
#
#
# Debería mostrarse algo así
#
# ```
# ---
# Corrales Solera, Iván — 41 años
# ---
# ```

# %%
# 👇 Tu solución

# %% [markdown]
# ### Actividad 6 - Manejo de diccionarios
#
# Crea un diccionario que represente un ordenador con estas claves:
# 	•	"marca"
# 	•	"ram_gb"
# 	•	"precio"
#
# Luego muestra solo la RAM.

# %%
# 👇 Tu solución

# %% [markdown]
# ## 9. Autoevaluación (quiz rápido)
# Marca mentalmente tu respuesta y **pruébala en código** si dudas.
#
# 1) ¿Qué imprime `bool('0')`? -> True
# 2) ¿Qué tipo devuelve `input()`? -> str
# 3) ¿Qué operador usarías para potencia? -> **
# 4) ¿Cómo formatearías un float a 2 decimales en un `f-string`? -> :.2f

# %% [markdown]
# ## 10. Siguientes pasos
# En el próximo notebook veremos **estructuras de control** (`if`, `for`, `while`) y construiremos un **menú interactivo**.
#
# Si te ha quedado alguna duda, añade una celda debajo con pruebas: aprender = experimentar 💡
